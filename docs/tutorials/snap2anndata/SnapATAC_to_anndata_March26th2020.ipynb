# %% [markdown]
# # Load Python packages

# %%
import rpy2
# enables the %%R magic
# %load_ext rpy2.ipython

from rpy2 import robjects
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
readRDS = robjects.r['readRDS']

import pandas as pd
from warnings import warn


import episcanpy.api as epi
import scanpy as sc
import anndata as ad

import anndata2ri
anndata2ri.activate()
# Out:
# /Users/annadanese/opt/anaconda3/lib/python3.7/site-packages/scanpy/api/__init__.py:7: FutureWarning:
#
# In a future version of Scanpy, `scanpy.api` will be removed.
# Simply use `import scanpy as sc` and `import scanpy.external as sce` instead.
#
#   FutureWarning,

# %%
#import episcanpy
print('rpy2 --> ', ad.__version__)
print('anndata2ri -->', anndata2ri.__version__)
print('anndata -->', ad.__version__)
print('scanpy -->', sc.__version__)
print('episcanpy -->', epi.__version__)
# Out:
# rpy2 -->  0.7.1
# anndata2ri --> 0.0.0
# anndata --> 0.7.1
# scanpy --> 1.4.7.dev1+g05703097
# episcanpy --> 0.1.10+3.g70e568e

# %%
print('rpy2 --> ', ad.__version__)
print('anndata2ri -->', anndata2ri.__version__)
print('anndata -->', ad.__version__)
print('scanpy -->', sc.__version__)
print('episcanpy -->', epi.__version__)
# Out:
# rpy2 -->  0.7.3
# anndata2ri --> 1.0.2
# anndata --> 0.7.3
# scanpy --> 1.5.1
# episcanpy --> 0.2.0

# %% [markdown]
# # Load R package(s)

# %%
# %%R
# R.version
# Out:
#                _
# platform       x86_64-apple-darwin13.4.0
# arch           x86_64
# os             darwin13.4.0
# system         x86_64, darwin13.4.0
# status
# major          3
# minor          6.1
# year           2019
# month          07
# day            05
# svn rev        76782
# language       R
# version.string R version 3.6.1 (2019-07-05)
# nickname       Action of the Toes

# %% [markdown]
# ### import R's "SnapATAC" package

# %%
snapatac = importr('SnapATAC')
# Out:
# ---------------------------------------------------------------------------
# PackageNotInstalledError                  Traceback (most recent call last)
# <ipython-input-4-45e91472dee0> in <module>
# ----> 1 snapatac = importr('SnapATAC')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/rpy2/robjects/packages.py in importr(name, lib_loc, robject_translations, signature_translation, suppress_messages, on_conflict, symbol_r2python, symbol_resolve, data)
#     469     if not isinstalled(name, lib_loc=lib_loc):
#     470         raise PackageNotInstalledError(
# --> 471             'The R package "%s" is not installed.' % name
#     472         )
#     473
#
# PackageNotInstalledError: The R package "SnapATAC" is not installed.

# %% [markdown]
# #### If you need to install SnapATAC:

# %%
# %%R
# #install.packages("devtools", repos='https://ftp.igh.cnrs.fr/pub/CRAN/', dependencies=TRUE, quiet=TRUE)
# #devtools::install_github("hadley/devtools")
# #library(devtools)
# #install_github("r3fang/SnapATAC")
# install_github("r3fang/SnapATAC", repo=NULL, type="source")
# #install.packages("SnapATAC", repos='https://ftp.igh.cnrs.fr/pub/CRAN/', dependencies=TRUE, quiet=TRUE)
# Out:
# R[write to console]: Downloading GitHub repo r3fang/SnapATAC@master
# These packages have more recent versions available.
# Which would you like to update?
#
#  1:   All
#  2:   CRAN packages only
#  3:   None
#  4:   MASS        (7.3-51.3 -> 7.3-51.6) [CRAN]
#  5:   Matrix      (1.2-17   -> 1.2-18  ) [CRAN]
#  6:   R6          (2.4.0    -> 2.4.1   ) [CRAN]
#  7:   Rcpp        (1.0.1    -> 1.0.5   ) [CRAN]
#  8:   backports   (1.1.4    -> 1.1.8   ) [CRAN]
#  9:   callr       (3.2.0    -> 3.4.3   ) [CRAN]
# 10:   cli         (1.1.0    -> 2.0.2   ) [CRAN]
# 11:   digest      (0.6.18   -> 0.6.25  ) [CRAN]
# 12:   ellipsis    (0.1.0    -> 0.3.1   ) [CRAN]
# 13:   evaluate    (0.13     -> 0.14    ) [CRAN]
# 14:   fansi       (0.4.0    -> 0.4.1   ) [CRAN]
# 15:   foreach     (1.4.4    -> 1.5.0   ) [CRAN]
# 16:   ggplot2     (3.1.1    -> 3.3.2   ) [CRAN]
# 17:   glue        (1.3.1    -> 1.4.1   ) [CRAN]
# 18:   iterators   (1.0.10   -> 1.0.12  ) [CRAN]
# 19:   lattice     (0.20-38  -> 0.20-41 ) [CRAN]
# 20:   mgcv        (1.8-28   -> 1.8-31  ) [CRAN]
# 21:   nlme        (3.1-139  -> 3.1-148 ) [CRAN]
# 22:   pillar      (1.3.1    -> 1.4.6   ) [CRAN]
# 23:   pkgbuild    (1.0.3    -> 1.1.0   ) [CRAN]
# 24:   pkgconfig   (2.0.2    -> 2.0.3   ) [CRAN]
# 25:   pkgload     (1.0.2    -> 1.1.0   ) [CRAN]
# 26:   plyr        (1.8.4    -> 1.8.6   ) [CRAN]
# 27:   prettyunits (1.0.2    -> 1.1.1   ) [CRAN]
# 28:   processx    (3.3.0    -> 3.4.3   ) [CRAN]
# 29:   ps          (1.3.0    -> 1.3.4   ) [CRAN]
# 30:   rlang       (0.3.4    -> 0.4.7   ) [CRAN]
# 31:   rstudioapi  (0.10     -> 0.11    ) [CRAN]
# 32:   scales      (1.0.0    -> 1.1.1   ) [CRAN]
# 33:   sp          (1.3-1    -> 1.4-2   ) [CRAN]
# 34:   tibble      (2.1.1    -> 3.0.3   ) [CRAN]
# 35:   withr       (2.1.2    -> 2.2.0   ) [CRAN]
# Enter one or more numbers separated by spaces, or an empty line to cancel
# 1: 3
# R[write to console]: Installing 26 packages: GenomeInfoDb, GenomicRanges, IRanges, RANN, RCurl, Rhdf5lib, Rtsne, S4Vectors, XVector, bigmemory, bigmemory.sri, doParallel, edgeR, farver, igraph, irlba, isoband, lifecycle, limma, locfit, raster, rhdf5, testthat, vctrs, viridis, zlibbioc
#
# R[write to console]: also installing the dependencies ‘rlang’, ‘sp’, ‘ellipsis’
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/rlang_0.4.7.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 847308 bytes (827 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 827 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/sp_1.4-2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1135318 bytes (1.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.1 MB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/ellipsis_0.3.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 7582 bytes
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 7582 bytes
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/GenomeInfoDb_1.18.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3404667 bytes (3.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 3.2 MB
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/GenomicRanges_1.34.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1159067 bytes (1.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.1 MB
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/IRanges_2.16.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 457397 bytes (446 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 446 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/RANN_2.6.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 58136 bytes (56 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 56 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/RCurl_1.98-1.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 699583 bytes (683 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 683 KB
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/Rhdf5lib_1.4.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 9222338 bytes (8.8 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 8.8 MB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/Rtsne_0.15.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 67595 bytes (66 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 66 KB
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/S4Vectors_0.20.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 633420 bytes (618 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 618 KB
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/XVector_0.22.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 64494 bytes (62 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 62 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/bigmemory_4.5.36.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 70120 bytes (68 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 68 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/bigmemory.sri_0.1.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1790 bytes
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1790 bytes
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/doParallel_1.0.15.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 173578 bytes (169 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 169 KB
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/edgeR_3.24.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1470609 bytes (1.4 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.4 MB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/farver_2.0.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1279579 bytes (1.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.2 MB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/igraph_1.2.5.tar.gz'
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2726569 bytes (2.6 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.6 MB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/irlba_2.3.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 234753 bytes (229 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 229 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/isoband_0.2.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2295931 bytes (2.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.2 MB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/lifecycle_0.2.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 164455 bytes (160 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 160 KB
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/limma_3.38.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1471609 bytes (1.4 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.4 MB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/locfit_1.5-9.4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 200998 bytes (196 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 196 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/raster_3.3-13.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 574517 bytes (561 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 561 KB
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/rhdf5_2.26.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 504692 bytes (492 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 492 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/testthat_2.3.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 249661 bytes (243 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 243 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/vctrs_0.3.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 958372 bytes (935 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 935 KB
#
#
# R[write to console]: versuche URL 'https://cloud.r-project.org/src/contrib/viridis_0.5.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1906320 bytes (1.8 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.8 MB
#
#
# R[write to console]: versuche URL 'https://bioconductor.org/packages/3.8/bioc/src/contrib/zlibbioc_1.28.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 257463 bytes (251 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 251 KB
#
#
# R[write to console]: Fehler in i.p(...) :
#   (konvertiert von Warnung) installation of package ‘rlang’ had non-zero exit status
# Fehler in i.p(...) :
#   (konvertiert von Warnung) installation of package ‘rlang’ had non-zero exit status

# %%
# %%R
# #install.packages("rlang", repo=NULL, type="source")
# library(sp)

# %%
# %%R
# #install.packages("devtools", repos='https://ftp.igh.cnrs.fr/pub/CRAN/', quiet=TRUE)
# install.packages(c("devtools", "roxygen2", "testthat", "knitr"),
#                  repos='https://ftp.igh.cnrs.fr/pub/CRAN/',
#                  quiet=TRUE)
# #devtools::install_github("hadley/devtools")
# #library(devtools)
# #install_github("r3fang/SnapATAC")
# Out:
# R[write to console]: also installing the dependencies ‘sys’, ‘ps’, ‘askpass’, ‘fs’, ‘gh’, ‘git2r’, ‘glue’, ‘processx’, ‘fansi’, ‘promises’, ‘openssl’, ‘xopen’, ‘usethis’, ‘callr’, ‘cli’, ‘covr’, ‘DT’, ‘ellipsis’, ‘httr’, ‘jsonlite’, ‘pkgbuild’, ‘pkgload’, ‘rcmdcheck’, ‘rlang’, ‘sessioninfo’, ‘commonmark’, ‘purrr’, ‘yaml’, ‘xfun’
#
#
# R[write to console]: Updating HTML index of packages in '.Library'
#
# R[write to console]: Making 'packages.html' ...
# R[write to console]:  done

# %%
# %%R
# library(devtools)
# Out:
# R[write to console]: Fehler in library(devtools) : es gibt kein Paket namens ‘devtools’
#
# R[write to console]: Zusätzlich:
# R[write to console]: Es gab 50 oder mehr Warnungen (Anzeige der ersten 50 mit warnings())
# R[write to console]:
# Fehler in library(devtools) : es gibt kein Paket namens ‘devtools’

# %% [markdown]
# # Load functions

# %%
def digRS4(RS4, verbose=True):
    """
    Extract elements of an RS4 object.
    
    """
    output_list = [type(RS4), RS4.rclass, RS4.slots.keys()]
    
    if verbose:
        print('running function digRS4')
        print(type(RS4), RS4.rclass)
        print('elements of the RS4', RS4.slots.keys())
        
    # go through the different elements, extract the data and store it in a list
    for i in tuple(RS4.slots.keys()):
        list_type = []
        type_i = type(RS4.slots[i]) # extract the type of the element extracted. 
        if verbose:
            print(tuple(RS4.rclass), '\t', i, type(RS4.slots[i]))
        # if the element is not an RS4 you simply store it in the list
        if type_i != rpy2.robjects.methods.RS4:
            list_type.append(RS4.slots[i])
        # if the element is an RS4 we call this function to go one step deeper 
        ### WARNING: need to check it is not and endless loop
        else:
            if verbose:
                print('ERROR: RS4 object containing RS4')
            list_type.append(digRS4(RS4.slots[i], verbose=verbose))
        output_list.append(list_type)
    return(output_list)


def extract_snap(rds_file_name, verbose=True):
    """
    reads an rds file containing a snap object. 
    Outputs an anndata matrix
    
    Warning:
    the current version do not transfer Granges information
    
    Input:
    ------
    
    rds_file_name --> file name, it had to be an rds file
    
    verbosity --> If True, prints information regarding the different steps to read
    and convert thesnap object into an anndata.
    
    save --> if a file name specified, it will save the file as h5ad
    
    Output:
    -------
    Anndata object
    
    """
    #### Load the snao object and check what's in it
    if verbose:
        print('READ THE RDS FILE:\n')
    snap = readRDS(rds_file_name)
    
    
    if verbose:
        # print the type and the class of snap
        print(type(snap), tuple(snap.rclass))
        # print keys
        print('keys: \t', tuple(snap.slots.keys()))
    if 'snap' not in tuple(snap.rclass):
        warn('ERROR, the input file needs to be an rds file containing a snap object\n')
        return()
    elif verbose:
        print('continue with the snap object.\n\n\n')
    
    ############
    ###  extract the different elements of the snap object:
    if verbose:
        print('EXTRACT ELEMENTS COMPOSING THE SNAP OBJECT:\n')
        
    #extract all elements to export into the Anndata that are not RS4 themself
    elements = {}
    # go through the individual elements of the snap object
    for n in tuple(snap.slots.keys()):
        if verbose:
            print(n, type(snap.slots[n]))
            
        #######
        # the case of RS4 and GRanges
        if type(snap.slots[n]) == rpy2.robjects.methods.RS4 and ('GRanges' in snap.slots[n].rclass):
            
            tmp_list = [type(snap.slots[n]), tuple(snap.slots[n].rclass)]
            warn(''.join(['\n', n, 'partially excluded from the conversion.\n GRanges are not currently fully transfered into the Anndata.\n']))
            granges = snap.slots[n]
            tmp_list.append(tuple(granges.slotnames()))
            
            tmp_dict={}
            for m in tuple(granges.slotnames()):
                if verbose:
                    print(m, type(granges.slots[m]))
                # only salvage the elements that are not RS4
                if type(granges.slots[m]) != rpy2.robjects.methods.RS4:
                    tmp_dict[m] = granges.slots[m]
                else:
                    tmp_list2 = []
                    tmp_feat = granges.slots[m]
                    for p in tuple(tmp_feat.slotnames()):
                        if verbose:
                            print('\t', p, type(tmp_feat.slots[p]))
                        tmp_list2.append([p, type(tmp_feat.slots[p]), tmp_feat.slots[p]])
                    
                    tmp_dict[m] = [tuple(granges.slots[m].slotnames()), tmp_list2]
                tmp_list.append(tmp_dict)

            elements[n] = tmp_list
            del tmp_list, tmp_list2, tmp_dict
            if verbose:
                print('\n')
        
        #######
        # the case of RS4 (not GRanges)
        # if the object is an RS4 we will call a function toextract the subparts:
        elif type(snap.slots[n]) == rpy2.robjects.methods.RS4:
            if verbose:
                print('\nRS4 object: ', n, tuple(snap.slots[n].rclass), tuple(snap.slots[n].slotnames()), '\n')
                
            ### call function
            elements[n] = digRS4(RS4=snap.slots[n], verbose=verbose)
            
            
        #######
        # the rest of the cases
        # if it is not an RS4 we simpoly convert it to a python data type and store it in the dictionary
        else:
            elements[n] = [type(snap.slots[n]), snap.slots[n]]
            
            
    return(elements)


def make_Anndata(input_data,
                 mtx_name='bmat',
                 feature_names=None,
                 metadata_name='metaData', 
                 jaccard=True,
                 jaccard_key='jmat',
                 save_all_rds=False,
                 save=None,
                 copy=True):
    """
    Currently, having multiple layers isn't possible.
    It is possible to add the jaccard matrix.
    
    """
    
    adata = ad.AnnData(X=input_data[mtx_name][1],
            obs=input_data['metaData'][1])

    if feature_names != None:
        if 'GRanges' in input_data[feature_names][1]:
            adata.var = input_data[feature_names][3]['elementMetadata']
            
    ## extra annotations ?
    extra_annot = ['barcode', 'file', 'cluster', 'sample']
    for extra in extra_annot:

        if (extra in input_data.keys()) and (extra not in adata.obs.columns) and (len(input_data[extra][1].tolist()) == len(adata.obs_names.tolist())):
            adata.obs[extra] = input_data[extra][1].tolist()
            
        
    
    # save the class snap:
    if 'class' in input_data.keys():
        adata.uns['class'] = input_data['class'][1]
    
    ## Add tsne, umap
    for n in ['tsne', 'umap']:
        if n in input_data.keys():
            name = ''.join(['X_',n,'_snap'])
            if input_data[n][1].shape == (len(adata.obs_names.tolist()), 2):
                adata.obsm[name] = input_data[n][1]
            else:
                warn(''.join(['WARNING: the dimension of ',
                              n,
                              ' does not match the expected shape. Therefore it is stored in adata.uns\n']))
                adata.uns[name] = input_data[n]
                
            
    if jaccard and (jaccard_key in input_data.keys()):
        
        ## check that the jaccard distance was computed properly
        if mtx_name not in input_data[jaccard_key][8][0]:
            warn(''.join(['WARNING: the jaccard distance is not computed using ', mtx_name, '\n',
                 'The jaccard distance was computed for: ', str(input_data[jaccard_key][8][0]), '\n']))
            
        adata.uns['jaccard'] = {'index':input_data[jaccard_key][3][0],
                                'normalised':input_data[jaccard_key][4][0],
                                'params':{'mtx': input_data[jaccard_key][8][0],
                                          'vector1': input_data[jaccard_key][5][0],
                                          'vector2': input_data[jaccard_key][6][0]
                                         }
                               }
    # save the rest in uns
    if save_all_rds:
        for n in input_data.keys():
            adata.uns[n] = input_data[n]
         
    if save!=None:
        save = save.rstrip('.h5ad')
        adata.write('.'.join([save, 'h5ad']))
        
    if copy:
        return(adata)
    
    
    
def snap2anndata(rds_file_name,
                 path='',
                 mtx_name='bmat',
                 feature_names='feature',
                 metadata_name='metaData', 
                 jaccard=True,
                 jaccard_key='jmat',
                 save_all_rds=False,
                 verbose=False,
                 copy=True,
                 save=None):
    """
    Convert a snap object saved as .rds into an Anndata object.
    
    In the current version of this function, you cannot store multiple matrices in 
    different layers of the anndata. 
    
    Input:
    ------
    * rds_file_name [str] --> the name of the inpout file
    
    * path [str] --> the path to the rds file - default: ''
    
    * mtx_name [str] --> matrix/featurespace extracted for the anndata.X - default: 'bmat'
    
    * feature_names [NoneType or str] --> key to extract the variable names (stored as GRanges in
      snap object) if specified - default: 'feature'
    
    * metadata_name [str] --> key to extract the metadata table from the snap object
      (also includes the observation names)- default: 'metaData'
    
    * jaccard [bool] --> extract the jaccard distance if jaccard is True - default: True
    
    * jaccard_key [str] --> If jaccard is True, it will extract the jaccard information
      stored in the snap object under the jaccard_key - default: 'jmat'
    
    * save_all_rds [bool] --> save the entire snap object in the uns section of the Anndata
      object. It takes a lot of memory but can be used to extract the different count matrices
      stored in the snap object - default: False
    
    * verbose [bool] --> print intermediary results and comments if True - default: False
    
    * copy [bool] --> if copy is True, return an Anndata object. - default: True
    
    * save [NoneType or str]--> if save is specified, write the Anndata as .h5ad
       - default: None
    
    
    Output
    ------
    
    * Anndata object --> if copy=True
    
    * Write the anndata object (as h5ad)--> if the output file name is specified as save='output_name'.
        If the path to the output directory is not specified with the output name, the anndata is saved in the current directory.
    
    """
    if path != '':
        file_name = '/'+path.rstrip('/').lstrip('/')+'/'+ rds_file_name.lstrip('/')
    else:
        file_name = rds_file_name.lstrip('/')
    
    tmp_file = extract_snap(rds_file_name=file_name,
                            verbose=verbose)
    
    if copy:
        return(make_Anndata(input_data=tmp_file,
                            mtx_name=mtx_name,
                            feature_names=feature_names,
                            metadata_name=metadata_name, 
                            jaccard=jaccard,
                            jaccard_key=jaccard_key,
                            save_all_rds=save_all_rds,
                            save=save,
                            copy=True))
    else:
        make_Anndata(input_data=tmp_file,
                     mtx_name=mtx_name,
                     feature_names=feature_names,
                     metadata_name=metadata_name, 
                     jaccard=jaccard,
                     jaccard_key=jaccard_key,
                     save_all_rds=save_all_rds,
                     save=save,
                     copy=False)

# %% [markdown]
# # Convert a snap object into an anndata

# %%
adata = snap2anndata(rds_file_name='atac_v1_adult_brain_fresh_5k.snap.rds',
                 path='/Volumes/Hepatocytes/snapatac_to_episcanpy/',
                 mtx_name='bmat',
                 feature_names='feature',
                 metadata_name='metaData', 
                 jaccard=True,
                 jaccard_key='jmat',
                 save_all_rds=False,
                 verbose=False,
                 copy=True,
                 save='/Volumes/Hepatocytes/snapatac_to_episcanpy/atac_v1_adult_brain_fresh_5k.snap.h5ad')
adata
# Out:
#  UserWarning:/Users/anna.danese/anaconda3/envs/new_snapatac/lib/python3.6/site-packages/ipykernel_launcher.py:89:
# featurepartially excluded from the conversion.
#  GRanges are not currently fully transfered into the Anndata.
#
#  UserWarning:/Users/anna.danese/anaconda3/envs/new_snapatac/lib/python3.6/site-packages/ipykernel_launcher.py:89:
# peakpartially excluded from the conversion.
#  GRanges are not currently fully transfered into the Anndata.
#
#  UserWarning:/Users/anna.danese/anaconda3/envs/new_snapatac/lib/python3.6/site-packages/ipykernel_launcher.py:181: WARNING: the dimension of umap does not match the expected shape. Therefore it is stored in adata.uns
#
# ... storing 'file' as categorical
# ... storing 'sample' as categorical
# AnnData object with n_obs × n_vars = 4100 × 546206
#     obs: 'barcode', 'total', 'duplicate', 'chimeric', 'unmapped', 'lowmapq', 'mitochondrial', 'passed_filters', 'cell_id', 'is__cell_barcode', 'TSS_fragments', 'DNase_sensitive_region_fragments', 'enhancer_region_fragments', 'promoter_region_fragments', 'on_target_fragments', 'blacklist_region_fragments', 'peak_region_fragments', 'peak_region_cutsites', 'promoter_ratio', 'landmark', 'cluster', 'file', 'sample'
#     var: 'name'
#     uns: 'class', 'X_umap_snap', 'jaccard'
#     obsm: 'X_tsne_snap'

# %%
adata.obsm['X_tsne'] = adata.obsm['X_tsne_snap'].copy()
sc.pl.tsne(adata, color='cluster')
